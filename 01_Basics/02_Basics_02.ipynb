# %%
fruit = "Banana"
print(fruit)
# Out:
# Banana

# %%
print(type(fruit))
# Out:
# <class 'str'>

# %%
name = "    Manoj B   "
print(name)
# Out:
#     Manoj B

# %%
name = name.strip()
print(name)
# Out:
# Manoj B

# %%
name = "   Swapna  "
name.lstrip()
# Out:
# 'Swapna  '

# %%
name.rstrip()
# Out:
# '   Swapna'

# %%
name.strip()
# Out:
# 'Swapna'

# %%
name.lstrip().rstrip()
# Out:
# 'Swapna'

# %% [markdown]
# ### Relational Operators

# %%
marks_a = 143
marks_b = 136

# %%
print (marks_a > marks_b)
# Out:
# True

# %%
print(marks_a < marks_b)
# Out:
# False

# %%
print(marks_a == marks_b)
# Out:
# False

# %%
print(marks_a != marks_b)
# Out:
# True

# %%
print(marks_a >= marks_b)
# Out:
# True

# %%
a = "Data"
b = "Data "
print(a == b)
# Out:
# False

# %%
user_id = 123
password = "Manoj@510"
print(user_id == 100)
print(password == "Manoj@2112")
# Out:
# False
# False

# %% [markdown]
# ### Assignment Operators

# %%
a = 2 
print(a)
# Out:
# 2

# %%
a += 2
print(a)
# Out:
# 4

# %%
a *= 2
print(a)
# Out:
# 8

# %%
a -= 2
print(a)
# Out:
# 6

# %%
a /= 2

# %%
print(a)
# Out:
# 3.0

# %%
a //= 2
print(a)
# Out:
# 1.0

# %% [markdown]
# ### Logical Operators

# %%
bool_a = True
bool_b = False
print(bool_a and bool_b)
# Out:
# False

# %%
print(bool_a or bool_b)
# Out:
# True

# %%
print(not bool_a)
# Out:
# False

# %%
# club entry conditions
# Person should be over 18
# Person should have atleast INR 500 to enter in to the club

person_age = 20
person_age_threshold = 18
person_amount = 1000
minimum_amount = 500

# %%
(person_age >= person_age_threshold) and (person_amount >= minimum_amount)
# Out:
# True

# %% [markdown]
# ### Bitwise Operators

# %%
a = 3
b = 1
print(a & b)
print(a | b)
print(~ a)
print ( a ^ b)
# Out:
# 1
# 3
# -4
# 2

# %% [markdown]
# ### Conditional Statements or Control Flow

# %%
current_batch = 1
if(current_batch >= 2):
  print("Provided the access for the recordings of batch - 1 and batch - 2")
else:
  print("Provide the access for batch - 1 only")
# Out:
# Provide the access for batch - 1 only

# %%
if True:
  print("Hello Manoj")
# Out:
# Hello Manoj

# %%
operation_name = ""
if(operation_name == "add"):
  print("Perform Addition")
elif(operation_name == "subtract"):
  print("Perform Substraction")
else:
  print("No Selected Operation found")
# Out:
# No Selected Operation found

# %% [markdown]
# ### More Data Types

# %%
### list

fruits = ["apple", "banana" ,"berries"]
print(fruits)
print(type(fruits))
# Out:
# ['apple', 'banana', 'berries']
# <class 'list'>

# %%
lst = [67, 78.90, "Manoj" , "Trick"]
print(lst)
print(type(lst))
# Out:
# [67, 78.9, 'Manoj', 'Trick']
# <class 'list'>

# %%
lst.append("Balineni")
print(lst)
# Out:
# [67, 78.9, 'Manoj', 'Trick', 'Balineni', 'Balineni']

# %%
print(len(lst))
# Out:
# 6
