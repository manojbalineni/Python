# %%
print("Hello World")
# Out:
# Hello World

# %%
# Storing values in the varaibles
a = 100
print(a)
# Out:
# 100

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
b = "Manoj Babu"
print(b)
print(type(b))
# Out:
# Manoj Babu
# <class 'str'>

# %%
c = 3.10
print(type(c))
# Out:
# <class 'float'>

# %%
id(a)
# Out:
# 140705576083672

# %%
value = 12
value_1 = 12
print(id(value))
print(id(value_1))
# Out:
# 140705576080856
# 140705576080856

# %%
value_3 = 12.00
print(id(value_3))
# Out:
# 1484536469200

# %%
# This is the single line comment

# %%
'''
This is
the multiple 
line comments
'''
# Out:
# '\nThis is\nthe multiple \nline comments\n\n'

# %%
mentor_name = "Manoj"
print(mentor_name)
a = 10000
print(300)
age = 12
print(a)
# Out:
# Manoj
# 300
# 10000

# %%
isEligibleForVote = True
print(isEligibleForVote)
# Out:
# True

# %%
print(type(isEligibleForVote))
# Out:
# <class 'bool'>

# %% [markdown]
# ### Type Casting

# %%
salary = 10000
print(salary)

print(float(salary))
# Out:
# 10000
# 10000.0

# %%
temeparature = 45.78
print(temeparature)

print(int(temeparature))
# Out:
# 45.78
# 45

# %%
temeparature_str = str(temeparature)
print(temeparature_str)
print(type(temeparature_str))
# Out:
# 45.78
# <class 'str'>

# %%
bool_a = True
print(bool_a)
print(type(bool_a))
# Out:
# True
# <class 'bool'>

# %%
bool_int = int(bool_a)
print(bool_int)
print(type(bool_int))
# Out:
# 1
# <class 'int'>

# %% [markdown]
# ### Operators

# %%
# Arthematic Operators

2 + 2
# Out:
# 4

# %%
a = 100
b = 100
print(a + b)
# Out:
# 200

# %%
c = a + b
print(c)
# Out:
# 200

# %%
c = "Data Science " + 6
print(c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 c = "Data Science " + 6
#       2 print(c)
#
# TypeError: can only concatenate str (not "int") to str

# %%
firstName = "Manoj"
lastName = "Babu"
print(firstName + " " +lastName)
# Out:
# Manoj Babu

# %%
print(firstName * 3)
# Out:
# ManojManojManoj

# %%
2 + 2.990
# Out:
# 4.99

# %%
print(11 % 2)
print(11 / 2)
# Out:
# 1
# 5.5

# %%
print (6363 - 563)
# Out:
# 5800

# %%
print( 56 * 7)
# Out:
# 392

# %%
# floor division

print(67 // 6)
# Out:
# 11
