# %% [markdown]
# ### Libraray - OS

# %%
import os

# %%
os.getcwd()
# Out:
# 'c:\\Users\\Manoj\\OneDrive\\Desktop\\6 Months\\AI_Gen_AI_ML\\Python\\Python'

# %%
os.listdir()
# Out:
# ['01_Basics_01.ipynb',
#  '02_Basics_02.ipynb',
#  '03_Basics_03.ipynb',
#  '04_Basics_04.ipynb',
#  '05_String_Methods.ipynb',
#  '06_Loops.ipynb',
#  '07_Functions.ipynb',
#  '08_Library.ipynb',
#  'Assignment_1.ipynb',
#  'Assignment_2.ipynb']

# %%
os.listdir("c:/Users/Manoj/OneDrive/Desktop/6 Months/AI_Gen_AI_ML")
# Out:
# ['ML', 'Python', 'SQL']
