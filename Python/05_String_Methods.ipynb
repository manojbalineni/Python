# %% [markdown]
# ### String Methods

# %%
s = "   Data   "
print(s)
# Out:
#    Data

# %%
print(s.lstrip())
# Out:
# Data

# %%
print(s.rstrip())
# Out:
#    Data

# %%
name = "manoj"
print(name.upper())
# Out:
# MANOJ

# %%
program  = "DATA SCIENCE"
print(program.lower())
# Out:
# data science

# %%
s = "data science is trending topic"
print(s.capitalize())
# Out:
# Data science is trending topic

# %%
s = "WelComE"
print(s.swapcase())
# Out:
# wELcOMe

# %%
a = "artificial intelligence is every thing"
print(a.title())
# Out:
# Artificial Intelligence Is Every Thing

# %%
names = ["Manoj" , "Swapna" , "Vissu"]
print(" ".join(names))
# Out:
# Manoj Swapna Vissu

# %%
print(",".join(names))
# Out:
# Manoj,Swapna,Vissu

# %%
name = "bbabu39"
print(name.find("9"))
# Out:
# 6

# %%
print(name.find("8"))
# Out:
# -1

# %%
a = "artificial intelligence is every thing"
print(a.find("is"))
# Out:
# 24

# %%
s = "manoj,vissu,swapna"
print(s.split(","))
# Out:
# ['manoj', 'vissu', 'swapna']

# %%
first_name = "manoj"
last_name = "babu"
print(first_name + " " +  last_name)
# Out:
# manoj babu

# %%
names = ["Manoj" , "Swapna" , "Vissu"]
answer = ""
for i in names:
  answer = answer + i + ","

print(answer)
# Out:
# Manoj,Swapna,Vissu,
