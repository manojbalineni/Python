# %% [markdown]
# ### Non Primitive Data Types

# %%
lst = ["Hello", 10 , False , "Angular" , 78.76]
print(lst)
# Out:
# ['Hello', 10, False, 'Angular', 78.76]

# %%
print(lst[1])
# Out:
# 10

# %%
lst.append(100)
print(lst)
# Out:
# ['Hello', 10, False, 'Angular', 78.76, 100]

# %%
lst.pop()
# Out:
# 100

# %%
print(lst)
# Out:
# ['Hello', 10, False, 'Angular', 78.76]

# %%
print(lst[-1])
# Out:
# 78.76

# %%
print(lst[-3])
# Out:
# False

# %%
len("Manoj")
# Out:
# 5

# %%
print(len(lst))
# Out:
# 5

# %%
print(lst[len(lst) - 1])
# Out:
# 78.76

# %%
print(lst[90])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 print(lst[90])
#
# IndexError: list index out of range

# %%
lst = [1, 2, 3, 4, 5, 6, 7, 8]
print(lst)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
lst.pop()
# Out:
# 8

# %%
print(lst)
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
lst.pop(0)
print(lst)
# Out:
# [2, 3, 4, 5, 6, 7]

# %%
lst.pop(-1)
print(lst)
# Out:
# [2, 3, 4, 5, 6]

# %%
lst.append(6)
print(lst)
# Out:
# [2, 3, 4, 5, 6, 6]

# %%
lst.remove(6)
print(lst)
# Out:
# [2, 3, 4, 5, 6]

# %% [markdown]
# ### Dictonary

# %%
register = { "Manoj" : ["Hyderabad" , 23 , "IND"], 
            "Swapna" : ["Hyderabad" , 26 , "IND"] , 
            "Vissu" : ["Hyderabad" , 21 , "IND"]}

# %%
print(register)
# Out:
# {'Manoj': ['Hyderabad', 23, 'IND'], 'Swapna': ['Hyderabad', 26, 'IND'], 'Vissu': ['Hyderabad', 21, 'IND']}

# %%
print(register.keys())
# Out:
# dict_keys(['Manoj', 'Swapna', 'Vissu'])

# %%
print(register.values())
# Out:
# dict_values([['Hyderabad', 23, 'IND'], ['Hyderabad', 26, 'IND'], ['Hyderabad', 21, 'IND']])

# %%
print(register.get("Swapna"))
# Out:
# ['Hyderabad', 26, 'IND']

# %%
print(register["Swapna"])
# Out:
# ['Hyderabad', 26, 'IND']

# %%
print(register.get("Ramu"))
# Out:
# None

# %%
print(register["Ramu"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 print(register["Ramu"])
#
# KeyError: 'Ramu'

# %%
print(register.get("Ramu" , "No value present for the given key"))
# Out:
# No value present for the given key

# %%
keys = register.keys();
print(keys)
print(type(keys))
# Out:
# dict_keys(['Manoj', 'Swapna', 'Vissu'])
# <class 'dict_keys'>

# %%
values = register.values();
print(values)
print(type(values))
# Out:
# dict_values([['Hyderabad', 23, 'IND'], ['Hyderabad', 26, 'IND'], ['Hyderabad', 21, 'IND']])
# <class 'dict_values'>

# %%
print(list(register.keys()))
# Out:
# ['Manoj', 'Swapna', 'Vissu']

# %%
print(list(register.values()))
# Out:
# [['Hyderabad', 23, 'IND'], ['Hyderabad', 26, 'IND'], ['Hyderabad', 21, 'IND']]

# %%
students = {
  "Manoj" : [23,34,25],
  "Swapna" : [23,23,23],
  "Vissu" : [22,23,24]
}
print(students)
# Out:
# {'Manoj': [23, 34, 25], 'Swapna': [23, 23, 23], 'Vissu': [22, 23, 24]}

# %%
print(list(students.keys()))
# Out:
# ['Manoj', 'Swapna', 'Vissu']

# %%
print(list(students.values()))
# Out:
# [[23, 34, 25], [23, 23, 23], [22, 23, 24]]

# %%
for i in list(students.keys()):
  print(i)
# Out:
# Manoj
# Swapna
# Vissu

# %%
for i in list(students.values()):
  print(i)
# Out:
# [23, 34, 25]
# [23, 23, 23]
# [22, 23, 24]

# %% [markdown]
# ### Tuple

# %%
date_of_birth = (23, "Janauary", 2000)
print(date_of_birth)
# Out:
# (23, 'Janauary', 2000)

# %%
print(date_of_birth[0])
# Out:
# 23

# %%
date_of_birth[0] = 28
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 date_of_birth[0] = 28
#
# TypeError: 'tuple' object does not support item assignment

# %%
print(type(date_of_birth))
# Out:
# <class 'tuple'>

# %%
employee = {
  201 : {
  "name" : "Manoj Babu",
  "date_of_birth" : (23 , "Jan" , 2000),
  "mobile_number" : "9381439125"
  },
    202 : {
  "name" : "Swapna",
  "date_of_birth" : (28 , "Jan" , 2000),
  "mobile_number" : "9381439129"
  }
 }

# %%
print(employee)
# Out:
# {201: {'name': 'Manoj Babu', 'date_of_birth': (23, 'Jan', 2000), 'mobile_number': '9381439125'}, 202: {'name': 'Swapna', 'date_of_birth': (28, 'Jan', 2000), 'mobile_number': '9381439129'}}

# %%
employee[201]
# Out:
# {'name': 'Manoj Babu',
#  'date_of_birth': (23, 'Jan', 2000),
#  'mobile_number': '9381439125'}

# %%
employee[202]
# Out:
# {'name': 'Swapna',
#  'date_of_birth': (28, 'Jan', 2000),
#  'mobile_number': '9381439129'}

# %%
lst = [1, 2, 3]
print(lst)
# Out:
# [1, 2, 3]

# %%
lst[0] = 1000
print(lst)
# Out:
# [1000, 2, 3]

# %%
matrix = [[1, 2, 3], [4, 5, 6]]
print(matrix)
# Out:
# [[1, 2, 3], [4, 5, 6]]

# %%
print(matrix[0])
# Out:
# [1, 2, 3]

# %%
print(matrix[0][1])
# Out:
# 2

# %%
register_v2 = {
  101 : {
    "Name" : {
      "first_name" : "Babu",
      "last_name" : "Manoj"
    },
    "date_of_birth" : (23, "Jan", 2000),
    "mobile_number" : "9381439125"
  }
}

# %%
print(register_v2)
# Out:
# {101: {'Name': {'first_name': 'Babu', 'last_name': 'Manoj'}, 'date_of_birth': (23, 'Jan', 2000), 'mobile_number': '9381439125'}}

# %%
print(register_v2[101])
# Out:
# {'Name': {'first_name': 'Babu', 'last_name': 'Manoj'}, 'date_of_birth': (23, 'Jan', 2000), 'mobile_number': '9381439125'}

# %%
print(register_v2[101]["date_of_birth"])
# Out:
# (23, 'Jan', 2000)

# %%
type(register_v2[101]["date_of_birth"])
# Out:
# tuple

# %%
print(register_v2[101]["Name"]["first_name"])
# Out:
# Babu

# %%
print(register_v2.get(101).get("Name").get("last_name"))
# Out:
# Manoj

# %% [markdown]
# ### Set

# %%
guests = {"Manoj", "Swapna" , "Vissu", 1 , 1 , 2, 3 , "Manoj"}
print(guests)
# Out:
# {1, 2, 3, 'Swapna', 'Manoj', 'Vissu'}

# %%
alpha = { "a" , "n" , "c" , "h" , "q"}
print(alpha)
# Out:
# {'c', 'n', 'a', 'h', 'q'}

# %%
names = set()
s = ()
print(s)
print(names)
# Out:
# ()
# set()

# %%
dob = tuple()
t = ()
print(t)
print(dob)
# Out:
# ()
# ()

# %%
a = list()
b = []
print(b)
print(a)
# Out:
# []
# []

# %%
guests
# Out:
# {1, 2, 3, 'Manoj', 'Swapna', 'Vissu'}

# %%
guests.add("Ram")
print(guests)
# Out:
# {1, 2, 3, 'Swapna', 'Manoj', 'Vissu', 'Ram'}

# %%
alpha
# Out:
# {'a', 'c', 'h', 'n', 'q'}

# %%
sorted(alpha)
# Out:
# ['a', 'c', 'h', 'n', 'q']

# %%
alpha
# Out:
# {'a', 'c', 'h', 'n', 'q'}

# %%
alpha_reverse = sorted(alpha , reverse= True)
print(alpha_reverse)
# Out:
# ['q', 'n', 'h', 'c', 'a']
